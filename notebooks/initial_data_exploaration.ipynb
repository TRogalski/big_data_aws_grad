# %% [markdown]
# english-stackexchange-com dateset consits of:
# - Badges.xml
# - Comments.xml
# - PostHistory.xml
# - PostLinks.xml
# - Posts.xml
# - Tags.xml
# - Users.xml
# - Votes.xml

# %%
from pyspark.sql import SparkSession

# %%
PATH = "spark-xml_2.12-0.15.0.jar"

# %%
spark = SparkSession.builder.appName("spark-xml")\
.config("spark.jars.packages", "org.apache.spark:spark-hadoop-cloud_2.12:3.2.1")\
.config("spark.jars", PATH)\
.getOrCreate()
# .config("spark.jars", PATH).getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/ubuntu/miniconda3/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/home/ubuntu/miniconda3/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/ubuntu/.ivy2/cache
# The jars for the packages stored in: /home/ubuntu/.ivy2/jars
# org.apache.spark#spark-hadoop-cloud_2.12 added as a dependency
# ...

# %%
spark._jsc.hadoopConfiguration().set("fs.s3a.access.key", "ASIA5CTRO67ECQWINQXN")
spark._jsc.hadoopConfiguration().set("fs.s3a.secret.key", "rmj5g5GQwUDik+EpiSEGyAPaQJusjehDGM+RPW3y")
spark._jsc.hadoopConfiguration().set("fs.s3a.session.token", "")

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Tags.xml')

# %%
df.show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df.show()
# Out:
# +------+--------------+---+--------------+-----------+
# |_Count|_ExcerptPostId|_Id|      _TagName|_WikiPostId|
# +------+--------------+---+--------------+-----------+
# |  5772|          2880|  2|     etymology|       2879|
# | 13661|         14043|  7|       grammar|      14042|
# |    24|          null| 10|    short-form|       null|
# |   961|         21906| 11|capitalization|      21905|
# |   103|         43838| 16|        sports|      43837|
# |  2898|         18038| 21|   punctuation|      18037|
# |   407|         25766| 22|        quotes|      25765|
# |   502|         61142| 27|        speech|      61141|
# |   459|         36563| 28|    politeness|      36562|
# |    50|          null| 30|    verb-forms|       null|
# |  1061|         36550| 32|  conjunctions|      36549|
# |   859|          6739| 35|   possessives|       6738|
# |   576|         43138| 36|    apostrophe|      43137|
# |    32|         44820| 38|           esl|      44819|
# ...

# %% [markdown]
# #### df Tags

# %% [markdown]
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_Count", IntegerType, false),
#     StructField("_ExcerptPostId", StringType, true),
#     StructField("_Id", StringType, false),
#     StructField("_TagName", StringType, false),
#     StructField("_WikiPostId", StringType, true)
#   ))
# ```

# %%
df.show()
# Out:
# +------+--------------+---+--------------+-----------+
# |_Count|_ExcerptPostId|_Id|      _TagName|_WikiPostId|
# +------+--------------+---+--------------+-----------+
# |  5743|          2880|  2|     etymology|       2879|
# | 13562|         14043|  7|       grammar|      14042|
# |    24|          null| 10|    short-form|       null|
# |   957|         21906| 11|capitalization|      21905|
# |   102|         43838| 16|        sports|      43837|
# |  2882|         18038| 21|   punctuation|      18037|
# |   403|         25766| 22|        quotes|      25765|
# |   495|         61142| 27|        speech|      61141|
# |   460|         36563| 28|    politeness|      36562|
# |    50|          null| 30|    verb-forms|       null|
# |  1048|         36550| 32|  conjunctions|      36549|
# |   858|          6739| 35|   possessives|       6738|
# |   574|         43138| 36|    apostrophe|      43137|
# |    31|         44820| 38|           esl|      44819|
# ...

# %%
df.describe()
# Out:
# DataFrame[summary: string, _Count: string, _ExcerptPostId: string, _Id: string, _TagName: string, _WikiPostId: string]

# %%
df.describe().show()
# Out:
# +-------+------------------+------------------+------------------+-------------+------------------+
# |summary|            _Count|    _ExcerptPostId|               _Id|     _TagName|       _WikiPostId|
# +-------+------------------+------------------+------------------+-------------+------------------+
# |  count|               986|               531|               986|          986|               531|
# |   mean| 268.3894523326572|204965.82485875706|1279.5709939148073|         null|204964.82485875706|
# | stddev|1185.6223392892143|173824.62318046755| 761.5493808163409|         null|173824.62318046755|
# |    min|                 1|              2880|                 2|abbreviations|              2879|
# |    max|             19863|            595383|              2624|       zeugma|            595382|
# +-------+------------------+------------------+------------------+-------------+------------------+

# %%
df.filter(
    """
    _Count IS NULL 
    OR _ExcerptPostId IS NULL 
    OR _Id IS NULL 
    OR _TagName IS NULL 
    OR _WikiPostId IS NULL
    """
).count()
# Out:
# 455

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# +------+--------------+---+--------+-----------+
# |_Count|_ExcerptPostId|_Id|_TagName|_WikiPostId|
# +------+--------------+---+--------+-----------+
# |     0|           455|  0|       0|        455|
# +------+--------------+---+--------+-----------+

# %%
df.filter(col('_excerptPostId').isNull() & col('_WikiPostId').isNull()).count()
# Out:
# 455

# %% [markdown]
# _excerptPostId and _WikiPostId have NULLs in the same places

# %% [markdown]
# #### df Badges
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_Class", IntegerType, false),
#     StructField("_Id", StringType, false),
#     StructField("_Name", StringType, false),
#     StructField("_UserId", StringType, false)
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Badges.xml')

# %%
df.show(truncate=False)
# Out:
# +------+-----------------------+---+--------------+---------+-------+
# |_Class|_Date                  |_Id|_Name         |_TagBased|_UserId|
# +------+-----------------------+---+--------------+---------+-------+
# |3     |2010-08-05 19:11:16.523|1  |Autobiographer|false    |2      |
# |3     |2010-08-05 19:11:16.54 |2  |Autobiographer|false    |3      |
# |3     |2010-08-05 19:11:16.553|3  |Autobiographer|false    |4      |
# |3     |2010-08-05 19:21:16.533|4  |Autobiographer|false    |5      |
# |3     |2010-08-05 19:31:16.593|5  |Autobiographer|false    |6      |
# |3     |2010-08-05 19:36:16.897|6  |Autobiographer|false    |11     |
# |3     |2010-08-05 19:36:16.897|7  |Autobiographer|false    |15     |
# |3     |2010-08-05 19:41:16.76 |8  |Autobiographer|false    |17     |
# |3     |2010-08-05 19:41:16.777|9  |Autobiographer|false    |21     |
# |3     |2010-08-05 19:41:16.793|10 |Autobiographer|false    |22     |
# ...

# %%
df.describe()
# Out:
# DataFrame[summary: string, _Class: string, _Id: string, _Name: string, _UserId: string]

# %%
df.describe().show()
# Out:
# [Stage 7:=============================>                             (1 + 1) / 2]
# +-------+------------------+------------------+-------------+------------------+
# |summary|            _Class|               _Id|        _Name|           _UserId|
# +-------+------------------+------------------+-------------+------------------+
# |  count|            572074|            572074|       572074|            572074|
# |   mean| 2.768164608075179|321939.81443309784|         null|142706.48623255032|
# | stddev|0.4984087151098312|183188.29084160933|         null|131651.81020062772|
# |    min|                 1|                 1|     Altruist|                 2|
# |    max|                 3|            634101|writing-style|            464520|
# +-------+------------------+------------------+-------------+------------------+

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# [Stage 10:=============================>                            (1 + 1) / 2]
# +------+-----+---+-----+---------+-------+
# |_Class|_Date|_Id|_Name|_TagBased|_UserId|
# +------+-----+---+-----+---------+-------+
# |     0|    0|  0|    0|        0|      0|
# +------+-----+---+-----+---------+-------+

# %% [markdown]
# Seems there are no NULLs in this dataset

# %%
df.select("_Class").distinct().show()
# Out:
# [Stage 19:=============================>                            (1 + 1) / 2]
# +------+
# |_Class|
# +------+
# |     1|
# |     3|
# |     2|
# +------+

# %%
df.select("_Name").distinct().count()
# Out:
# 193

# %% [markdown]
# #### df Comments
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_ContentLicense", StringType, false),
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_Id", StringType, false),
#     StructField("_PostId", StringType, false),
#     StructField("_Score", IntegerType, false),
#     StructField("_Text", StringType, false),
#     StructField("_UserDisplayName", StringType, true),
#     StructField("_UserId", StringType, true)
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Comments.xml')

# %%
df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  _ContentLicense  | CC BY-SA 2.5
#  _CreationDate    | 2010-08-05 20:01:43.273
#  _Id              | 6
#  _PostId          | 23
#  _Score           | 13
#  _Text            | It's correct when you're accessing a method of a string literal in Python: "test,test".split(",")
#  _UserDisplayName | null
#  _UserId          | 36
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  _ContentLicense  | CC BY-SA 2.5
# ...

# %%
df.describe()
# Out:
# DataFrame[summary: string, _ContentLicense: string, _Id: string, _PostId: string, _Score: string, _Text: string, _UserDisplayName: string, _UserId: string]

# %%
df.describe().show(vertical=True, truncate=False)
# Out:
# [Stage 43:===================================================>     (9 + 1) / 10]
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary          | count
#  _ContentLicense  | 900927
#  _Id              | 900927
#  _PostId          | 900927
#  _Score           | 900927
#  _Text            | 900927
#  _UserDisplayName | 28432
#  _UserId          | 872494
# ...

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# [Stage 39:===================================================>     (9 + 1) / 10]
# +---------------+-------------+---+-------+------+-----+----------------+-------+
# |_ContentLicense|_CreationDate|_Id|_PostId|_Score|_Text|_UserDisplayName|_UserId|
# +---------------+-------------+---+-------+------+-----+----------------+-------+
# |              0|            0|  0|      0|     0|    0|          872495|  28433|
# +---------------+-------------+---+-------+------+-----+----------------+-------+

# %% [markdown]
# Quite a few comments do not have _UserDisplayName and _UserId

# %%
df.select("_Score").distinct().count()
# Out:
# 95

# %%
df.filter(
    """
    _UserDisplayName IS NULL
    """
).count()
# Out:
# 872495

# %%
df.count()
# Out:
# 900927

# %% [markdown]
# #### df PostHistory
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_Comment", StringType, true),
#     StructField("_ContentLicense", StringType, true),
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_Id", StringType, false),
#     StructField("_PostHistoryTypeId", StringType, false),
#     StructField("_PostId", StringType, false),
#     StructField("_RevisionGUID", StringType, false),
#     StructField("_Text", StringType, true),
#     StructField("_UserDisplayName", StringType, true),
#     StructField("_UserId", StringType, true)
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/PostHistory.xml')

# %%
df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------
#  _Comment           | null
#  _ContentLicense    | CC BY-SA 2.5
#  _CreationDate      | 2010-08-05 19:34:49.473
#  _Id                | 1
#  _PostHistoryTypeId | 2
#  _PostId            | 1
#  _RevisionGUID      | 706cd8ee-5f80-4f75-945f-ed2f5deb4e32
#  _Text              | when could I use can (or when can I use could ?) .. what is right under what context ?
#  _UserDisplayName   | null
#  _UserId            | 9
# -RECORD 1----------------------------------------------------------------------------------------------------
#  _Comment           | null
#  _ContentLicense    | CC BY-SA 2.5
#  _CreationDate      | 2010-08-05 19:34:49.473
#  _Id                | 2
#  _PostHistoryTypeId | 1
#  _PostId            | 1
#  _RevisionGUID      | 706cd8ee-5f80-4f75-945f-ed2f5deb4e32
#  _Text              | when do I could "Can" & "could" ?
#  _UserDisplayName   | null
# ...

# %%
df.describe().show()
# Out:
# [Stage 75:======================================================> (28 + 1) / 29]
# +-------+------------------------+---------------+-----------------+------------------+------------------+--------------------+---------------------+--------------------+------------------+
# |summary|                _Comment|_ContentLicense|              _Id|_PostHistoryTypeId|           _PostId|       _RevisionGUID|                _Text|    _UserDisplayName|           _UserId|
# +-------+------------------------+---------------+-----------------+------------------+------------------+--------------------+---------------------+--------------------+------------------+
# |  count|                  469779|        1060124|          1183712|           1183712|           1183712|             1183712|              1099790|               41522|           1094517|
# ...

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# [Stage 78:======================================================> (28 + 1) / 29]
# +--------+---------------+-------------+---+------------------+-------+-------------+-----+----------------+-------+
# |_Comment|_ContentLicense|_CreationDate|_Id|_PostHistoryTypeId|_PostId|_RevisionGUID|_Text|_UserDisplayName|_UserId|
# +--------+---------------+-------------+---+------------------+-------+-------------+-----+----------------+-------+
# |  713933|         123588|            0|  0|                 0|      0|            0|83922|         1142190|  89195|
# +--------+---------------+-------------+---+------------------+-------+-------------+-----+----------------+-------+

# %% [markdown]
# #### df PostLinks
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_Id", StringType, false),
#     StructField("_LinkTypeId", StringType, false),
#     StructField("_PostId", StringType, false),
#     StructField("_RelatedPostId", StringType, false)
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/PostLinks.xml')

# %%
df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  _CreationDate  | 2010-08-09 23:26:52.773
#  _Id            | 80
#  _LinkTypeId    | 1
#  _PostId        | 331
#  _RelatedPostId | 56
# -RECORD 1---------------------------------
#  _CreationDate  | 2010-08-14 19:27:48.777
#  _Id            | 133
#  _LinkTypeId    | 1
#  _PostId        | 170
#  _RelatedPostId | 861
# only showing top 2 rows

# %%
df.describe().show()
# Out:
# [Stage 81:===============>(28 + 1) / 29][Stage 84:>                 (0 + 1) / 1]
# +-------+------------------+------------------+------------------+------------------+
# |summary|               _Id|       _LinkTypeId|           _PostId|    _RelatedPostId|
# +-------+------------------+------------------+------------------+------------------+
# |  count|             70412|             70412|             70412|             70412|
# |   mean| 7062070.326833494|1.5321252059308073| 314143.5956229052|120182.49177696984|
# | stddev|3161736.3670830326|0.8838010355362302|175356.40836057192|137288.38529012253|
# |    min|                80|                 1|                 1|                 1|
# |    max|          12361098|                 3|            595693|           5056980|
# +-------+------------------+------------------+------------------+------------------+

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# [Stage 87:>                                                         (0 + 1) / 1]
# +-------------+---+-----------+-------+--------------+
# |_CreationDate|_Id|_LinkTypeId|_PostId|_RelatedPostId|
# +-------------+---+-----------+-------+--------------+
# |            0|  0|          0|      0|             0|
# +-------------+---+-----------+-------+--------------+

# %% [markdown]
# #### df Posts
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_AcceptedAnswerId", StringType, true),
#     StructField("_AnswerCount", IntegerType, true),
#     StructField("_Body", StringType, false),
#     StructField("_ClosedDate", Timestamp, true),
#     StructField("_CommentCount", IntegerType, false),
#     StructField("_CommunityOwnedDate", Timestamp, true),
#     StructField("_ContentLicense", StringType, false),
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_FavoriteCount", IntegerType, true),
#     StructField("_Id", StringType, false),
#     StructField("_LastActivityDate", Timestamp, false),
#     StructField("_LastEditDate", Timestamp, true),
#     StructField("_LastEditorDisplayName", StringType, true),
#     StructField("_LastEditorUserId", StringType, true),
#     StructField("_OwnerDisplayName", StringType, true),
#     StructField("_LastEditorUserId", StringType, true),
#     StructField("_OwnerDisplayName", StringType, true),
#     StructField("_OwnerUserId", StringType, true),
#     StructField("_ParentId", StringType, true),
#     StructField("_PostTypeId", StringType, false),
#     StructField("_Score", IntegerType, false),
#     StructField("_Tags", StringType, true),
#     StructField("_Title", StringType, true),
#     StructField("_ViewCount", IntegerType, true),
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Posts.xml')

# %%
df.filter("_ClosedDate IS NOT NULL").show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  _AcceptedAnswerId      | 39
#  _AnswerCount           | 6
# ...

# %%
df.describe().show(truncate=False, vertical=True)
# Out:
# [Stage 101:===================================================>   (15 + 1) / 16]
# -RECORD 0------------------------------------------------------------------------------------------------
#  summary                | count
#  _AcceptedAnswerId      | 60549
#  _AnswerCount           | 126374
#  _Body                  | 410638
#  _CommentCount          | 410638
#  _ContentLicense        | 410638
#  _FavoriteCount         | 36449
#  _Id                    | 410638
#  _LastEditorDisplayName | 7616
#  _LastEditorUserId      | 174071
#  _OwnerDisplayName      | 15385
#  _OwnerUserId           | 396051
#  _ParentId              | 282944
#  _PostTypeId            | 410638
#  _Score                 | 410638
#  _Tags                  | 126374
#  _Title                 | 126374
#  _ViewCount             | 126374
# -RECORD 1------------------------------------------------------------------------------------------------
#  summary                | mean
# ...

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show(vertical=True)
# Out:
# [Stage 98:====================================================>   (15 + 1) / 16]
# -RECORD 0------------------------
#  _AcceptedAnswerId      | 350089
#  _AnswerCount           | 284264
#  _Body                  | 0
#  _ClosedDate            | 377099
#  _CommentCount          | 0
#  _CommunityOwnedDate    | 408896
#  _ContentLicense        | 0
#  _CreationDate          | 0
#  _FavoriteCount         | 374189
#  _Id                    | 0
#  _LastActivityDate      | 0
#  _LastEditDate          | 230272
#  _LastEditorDisplayName | 403022
#  _LastEditorUserId      | 236567
#  _OwnerDisplayName      | 395253
#  _OwnerUserId           | 14587
#  _ParentId              | 127694
#  _PostTypeId            | 0
#  _Score                 | 0
#  _Tags                  | 284264
#  _Title                 | 284264
#  _ViewCount             | 284264

# %% [markdown]
# #### df Users
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_AboutMe", StringType, true),
#     StructField("_AccountId", StringType, true),
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_DisplayName", StringType, false),
#     StructField("_DownVotes", IntegeType, false),
#     StructField("_Id", StringType, false),
#     StructField("_LastAccessDate", Timestamp, false),
#     StructField("_Location", StringType, true),
#     StructField("_ProfileImageUrl", StringType, true),
#     StructField("_Reputation", IntegerType, false),
#     StructField("_UpVotes", IntegerType, false),
#     StructField("_Views", IntegerType, false),
#     StructField("_WebsiteUrl", StringType, true),
#
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Users.xml')

# %%
df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df.describe().show(truncate=False, vertical=True)
# Out:
# [Stage 107:============================>                            (2 + 2) / 4]
# -RECORD 0-------------------------------------------------------------------------------------------------------
#  summary          | count
#  _AboutMe         | 89049
#  _AccountId       | 366067
#  _DisplayName     | 366083
#  _DownVotes       | 366083
#  _Id              | 366083
#  _Location        | 97490
#  _ProfileImageUrl | 249674
#  _Reputation      | 366083
#  _UpVotes         | 366083
#  _Views           | 366083
#  _WebsiteUrl      | 62300
# -RECORD 1-------------------------------------------------------------------------------------------------------
#  summary          | mean
#  _AboutMe         | null
#  _AccountId       | 1.013227254019073E7
#  _DisplayName     | NaN
#  _DownVotes       | 0.9097144636598804
#  _Id              | 255518.44996353285
#  _Location        | NaN
#  _ProfileImageUrl | null
#  _Reputation      | 68.18131680520538
#  _UpVotes         | 4.377559187397393
# ...

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show(vertical=True)
# Out:
# [Stage 110:==========================================>              (3 + 1) / 4]
# -RECORD 0------------------
#  _AboutMe         | 277034
#  _AccountId       | 16
#  _CreationDate    | 0
#  _DisplayName     | 0
#  _DownVotes       | 0
#  _Id              | 0
#  _LastAccessDate  | 0
#  _Location        | 268593
#  _ProfileImageUrl | 116409
#  _Reputation      | 0
#  _UpVotes         | 0
#  _Views           | 0
#  _WebsiteUrl      | 303783

# %% [markdown]
# #### df Votes
#
# Suggested schema:
# ```
#   StructType(Array(
#     StructField("_BountyAmount", IntegerType, true),
#     StructField("_CreationDate", Timestamp, false),
#     StructField("_Id", StringType, false),
#     StructField("_PostId", StringType, false),
#     StructField("_UserId", StringType, true),
#     StructField("_VoteTypeId", StringType, false)
#   ))
# ```

# %%
df = spark.read.format('xml').options(rowTag='row', rootTag='tags').load('s3a://english-stackexchange-com/raw/Votes.xml')

# %%
df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------
#  _BountyAmount | null
#  _CreationDate | 2010-08-05 00:00:00
#  _Id           | 1
#  _PostId       | 11
#  _UserId       | null
#  _VoteTypeId   | 2
# -RECORD 1----------------------------
#  _BountyAmount | null
#  _CreationDate | 2010-08-05 00:00:00
#  _Id           | 2
#  _PostId       | 3
#  _UserId       | null
#  _VoteTypeId   | 2
# only showing top 2 rows

# %%
df.describe().show(truncate=False, vertical=True)
# Out:
# [Stage 115:================================================>        (6 + 1) / 7]
# -RECORD 0---------------------------
#  summary       | count
#  _BountyAmount | 2430
#  _Id           | 2249886
#  _PostId       | 2249886
#  _UserId       | 80183
#  _VoteTypeId   | 2249886
# -RECORD 1---------------------------
#  summary       | mean
#  _BountyAmount | 112.43827160493827
#  _Id           | 1265168.13302674
#  _PostId       | 243353.56653492665
#  _UserId       | 130348.17851664318
#  _VoteTypeId   | 2.952770940394313
# -RECORD 2---------------------------
#  summary       | stddev
#  _BountyAmount | 108.29563671900993
#  _Id           | 719465.7194979889
#  _PostId       | 176850.1231962539
#  _UserId       | 119156.28630874347
#  _VoteTypeId   | 2.6873071136049234
# -RECORD 3---------------------------
#  summary       | min
#  _BountyAmount | 0
#  _Id           | 1
#  _PostId       | 1
#  _UserId       | -1
#  _VoteTypeId   | 1
# -RECORD 4---------------------------
# ...

# %%
from pyspark.sql.functions import col, when, count
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show(vertical=True)
# Out:
# [Stage 118:================================================>        (6 + 1) / 7]
# -RECORD 0----------------
#  _BountyAmount | 2247456
#  _CreationDate | 0
#  _Id           | 0
#  _PostId       | 0
#  _UserId       | 2169703
#  _VoteTypeId   | 0

# %%
FILE_CONFIG = {
    "Badges": {
            "column_types": {
                "_Class": "integer",
                "_Id": "string",
                "_Name": "string",
                "_UserId": "string"
            }
    },
    "Comments": {
            "column_types": {
                "_ContentLicense": "string",
                "_CreationDate": "timestamp",
                "_Id": "string",
                "_PostId": "string",
                "_Score": "integer",
                "_Text": "string",
                "_UserDisplayName": "string",
                "_UserId": "string",
            }
    },
    "PostHistory": {
            "column_types": {
                "_Comment": "string",
                "_ContentLicense": "string",
                "_CreationDate": "timestamp",
                "_Id": "string",
                "_PostHistoryTypeId": "string",
                "_PostId": "string",
                "_RevisionGUID": "string",
                "_Text": "string",
                "_UserDisplayName": "string",
                "_UserId": "string"
            }
    },
    "PostLinks": {
            "column_types": {
                "_Count": "integer",
                "_ExcerptPostId": "string",
                "_Id": "string",
                "_TagName": "string",
                "_WikiPostId": "string"
            }
    },
    "Posts": {
            "column_types": {
                "_AcceptedAnswerId": "string",
                "_AnswerCount": "integer",
                "_Body": "string",
                "_ClosedDate": "timestamp",
                "_CommentCount": "integer",
                "_CommunityOwnedDate": "timestamp",
                "_ContentLicense": "string",
                "_CreationDate": "timestamp",
                "_FavoriteCount": "integer",
                "_Id": "string",
                "_LastActivityDate": "timestamp",
                "_LastEdititDate": "timestamp",
                "_LastEditorDisplayName": "string",
                "_LastEditorUserId": "string",
                "_OwnerDisplayName": "string",
                "_OwnerUserId": "string",
                "_ParentId": "string",
                "_PostTypeId": "string",
                "_Score": "integer",
                "_Tags": "string",
                "_Title": "string",
                "_ViewCount": "integer"
            }
        },
    "Tags": {
            "column_types": {
                "_Count": "integer",
                "_ExcerptPostId": "string",
                "_Id": "string",
                "_TagName": "string",
                "_WikiPostId": "string"
            }
        },
    "Users": {
            "column_types": {
                "_AboutMe": "string",
                "_AccountId": "string",
                "_CreationDate": "timestamp",
                "_DisplayName": "string",
                "_DownVotes": "string",
                "_Id": "string",
                "_LastAccessDate": "timestamp",
                "_Location": "string",
                "_ProfileImageUrl": "string",
                "_Reputation": "integer",
                "_UpVotes": "integer",
                "_Views": "integer",
                "_WebsiteUrl": "string"
            }
    },
    "Votes": {
            "column_types": {
                "_BountyAmount": "integer",
                "_CreationDate": "timestamp",
                "_Id": "string",
                "_PostId": "string",
                "_UserId": "string",
                "_VoteTypeId": "string"
            }
    },
}

# %%
for k, v in FILE_CONFIG['Votes']['column_types'].items():
    print(k, v)
# Out:
# _BountyAmount integer
# _CreationDate timestamp
# _Id string
# _PostId string
# _UserId string
# _VoteTypeId string

# %%
import argparse

# %%
for element in FILE_CONFIG:
    print(FILE_CONFIG[element])
# Out:
# {'column_types': {'_Class': 'integer', '_Id': 'string', '_Name': 'string', '_UserId': 'string'}}
# {'column_types': {'_ContentLicense': 'string', '_CreationDate': 'timestamp', '_Id': 'string', '_PostId': 'string', '_Score': 'integer', '_Text': 'string', '_UserDisplayName': 'string', '_UserId': 'string'}}
# {'column_types': {'_Comment': 'string', '_ContentLicense': 'string', '_CreationDate': 'timestamp', '_Id': 'string', '_PostHistoryTypeId': 'string', '_PostId': 'string', '_RevisionGUID': 'string', '_Text': 'string', '_UserDisplayName': 'string', '_UserId': 'string'}}
# {'column_types': {'_Count': 'integer', '_ExcerptPostId': 'string', '_Id': 'string', '_TagName': 'string', '_WikiPostId': 'string'}}
# ...

# %%
   test='''"column_types": {         "_AboutMe": "string",
                "_AccountId": "string",
                "_CreationDate": "timestamp",
                "_DisplayName": "string",
                "_DownVotes": "string",
                "_Id": "string",
                "_LastAccessDate": "timestamp",
                "_Location": "string",
                "_ProfileImageUrl": "string",
                "_Reputation": "integer",
                "_UpVotes": "integer",
                "_Views": "integer",
                "_Websit'eUrl": "string"
            }'''

# %%
dict(str(FILE_CONFIG['Badges']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dict(str(FILE_CONFIG['Badges']))
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
str(FILE_CONFIG['Badges'])
# Out:
# "{'column_types': {'_Class': 'integer', '_Id': 'string', '_Name': 'string', '_UserId': 'string'}}"

# %%
import json

# %%
test2 = str(FILE_CONFIG['Badges'])

# %%
import ast

# %%
test2
# Out:
# "{'column_types': {'_Class': 'integer', '_Id': 'string', '_Name': 'string', '_UserId': 'string'}}"

# %%
ast.literal_eval(test2)
# Out:
# {'column_types': {'_Class': 'integer',
#   '_Id': 'string',
#   '_Name': 'string',
#   '_UserId': 'string'}}
